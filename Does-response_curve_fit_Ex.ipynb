# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x,A1,A2,LOGx0,p):
    return A1+(A2-A1)/(1+10**((LOGx0-x)*p))

xdata=np.linspace(-10,10,50)
y=func(xdata,1,2,-1,0.3)
y_noise=0.1*np.random.normal(size=xdata.size)
ydata=y+y_noise

plt.scatter(xdata,ydata,label='data')

popt, pcov = curve_fit(func2,xdata,ydata)
print(popt)
plt.plot(xdata, func2(xdata, *popt), 'r-', label=' A1=%5.5f\n A2=%5.5f\n LOGx0=%5.5f\n p=%5.5f' % tuple(popt))
plt.legend()
plt.show()
# Out:
# [ 1.01205147  2.00427112 -0.70807207  0.25932005]
